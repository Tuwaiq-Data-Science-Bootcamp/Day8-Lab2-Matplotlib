# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
# write your code here ^_^
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
# write your code here ^_^
np.x = [1,2, 3, 4, 5,6,7]
np.y=[1,2,3,5,8,13,20]
plt.plot(np.x,[1,2, 3, 4, 5,6,7] )
plt.plot(np.y,[1,2,3,5,8,13,20]);

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
# write your code here ^_^
np.x = [1,2, 3, 4, 5,6,7]
np.y=[1,2,3,5,8,13,20]
plt.plot([1,2, 3, 4, 5,6,7],marker = 'o',linestyle = '--',markersize = 10,linewidth = 3)
plt.plot([1,2,3,5,8,13,20],marker = 'o',linestyle = '--',markersize = 10,linewidth = 3)
plt.legend(['Normal','Fast'])

# %% [markdown]
# # Q4: Display multiple linear charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment
plt.figure(figsize=[10,5])
plt.suptitle('my data visulaization assignment',fontsize = 10)
#title = First Chart
plt.subplot(1,3,1)
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])
plt.plot([1, 2, 3, 4, 5, 6, 7])
plt.plot([1, 1, 2, 3, 5, 8, 13])
plt.title('one');


#title = Second Chart
plt.title('Two');
plt.subplot(1,3,2)
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])
plt.plot([0, 1, 2, 3, 4, 5, 6])
plt.plot([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
plt.title('Three');
plt.subplot(1,3,3)
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])
plt.plot([0, 1, 3, 4])
plt.plot([4, 6, 3, 4])

# %%
# write your code here ^_^

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
x= np.array(['Frinds','Modern family','Game of throns'])
y= np.array([10,8,9])
plt.bar(x, y)
plt.bar(x, y , width= 0.5 ,color='r')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
# write your code here ^_^

carAge= np.array([5,7,8,7,2,17,2,9,4,11])
carSpeed= np.array([99,86,87,88,111,86,103,87,94,78])
cars_colors = ['A', 'A', 'B', 'B', 'B', 'B', 'A', 'A', 'B', 'A']
colors = {'A':'orange', 'B':'blue'}
color_ls = [colors[i] for i in cars_colors]

plt.xlabel("x")
plt.ylabel("y")
plt.scatter(carAge,carSpeed,alpha = 0.4,s = 350,c=color_ls)

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %%
# write your code here ^_^
pythonLibrarie= np.array(['NumPay','Pands','Matplotlib','Seaborn','Plotly','Scikit-learn'])
skils= np.array([1,2,8,8,9,7])
lib_colors = ['A', 'B', 'C', 'D', 'E', 'F']
colors = {'A':'orange','B':'blue' , 'C' : 'white' , 'D':'black' ,'E' : 'red', 'F' : 'yallow'}
color_ls = [colors[i] for i in lib_colors]

plt.pie(skils,pythonLibrarie )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32584\1857453810.py in <module>
#       6 color_ls = [colors[i] for i in lib_colors]
#       7
# ----> 8 plt.pie(skils,pythonLibrarie )
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3087             theta2 = (theta1 + frac) if counterclock else (theta1 - frac)
#    3088             thetam = 2 * np.pi * 0.5 * (theta1 + theta2)
# -> 3089             x += expl * math.cos(thetam)
#    3090             y += expl * math.sin(thetam)
#    3091
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
# write your code here ^_^
x = np.random.randn(250) 
plt.hist(x,15);
